# %%
# !pip install naas
# !pip install naas_drivers
# Out:
# Collecting naas
#   Using cached naas-2.10.2-py3-none-any.whl
# Requirement already satisfied: pretty-cron==1.2.0 in c:\users\vp\anaconda3\lib\site-packages (from naas) (1.2.0)
# Requirement already satisfied: ipywidgets==7.6.5 in c:\users\vp\anaconda3\lib\site-packages (from naas) (7.6.5)
# Collecting APScheduler==3.8.1
#   Using cached APScheduler-3.8.1-py2.py3-none-any.whl (59 kB)
# Collecting beautifulsoup4==4.10.0
#   Using cached beautifulsoup4-4.10.0-py3-none-any.whl (97 kB)
# Requirement already satisfied: nest-asyncio==1.5.1 in c:\users\vp\anaconda3\lib\site-packages (from naas) (1.5.1)
# Requirement already satisfied: sanic==20.12.2 in c:\users\vp\anaconda3\lib\site-packages (from naas) (20.12.2)
# Requirement already satisfied: nbconvert==6.0.7 in c:\users\vp\anaconda3\lib\site-packages (from naas) (6.0.7)
# Requirement already satisfied: requests>=2.25.1 in c:\users\vp\anaconda3\lib\site-packages (from naas) (2.27.1)
# Collecting aiohttp==3.7.4.post0
#   Using cached aiohttp-3.7.4.post0-cp39-cp39-win_amd64.whl (634 kB)
# Requirement already satisfied: ipython==7.23.1 in c:\users\vp\anaconda3\lib\site-packages (from naas) (7.23.1)
# Requirement already satisfied: rich in c:\users\vp\anaconda3\lib\site-packages (from naas) (13.3.2)
#   WARNING: Legacy build of wheel for 'pysqlite3' created no files.
#   Command arguments: 'C:\Users\VP\anaconda3\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\VP\\AppData\\Local\\Temp\\pip-install-n04xz8fr\\pysqlite3_a27ed327797149a4b75e7060f9e1983a\\setup.py'"'"'; __file__='"'"'C:\\Users\\VP\\AppData\\Local\\Temp\\pip-install-n04xz8fr\\pysqlite3_a27ed327797149a4b75e7060f9e1983a\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d 'C:\Users\VP\AppData\Local\Temp\pip-wheel-n68_nfvc'
#   Command output: [use --verbose to show]
# Requirement already satisfied: pydash==5.1.0 in c:\users\vp\anaconda3\lib\site-packages (from naas) (5.1.0)
# Requirement already satisfied: MarkupSafe==2.0.1 in c:\users\vp\anaconda3\lib\site-packages (from naas) (2.0.1)
# Collecting markdown2==2.4.0
#   Using cached markdown2-2.4.0-py2.py3-none-any.whl (34 kB)
# Requirement already satisfied: psycopg2-binary==2.9.1 in c:\users\vp\anaconda3\lib\site-packages (from naas) (2.9.1)
# Requirement already satisfied: tzdata in c:\users\vp\anaconda3\lib\site-packages (from naas) (2022.7)
# Requirement already satisfied: pyvis==0.3.0 in c:\users\vp\anaconda3\lib\site-packages (from naas) (0.3.0)
# Requirement already satisfied: sanic-openapi==0.6.2 in c:\users\vp\anaconda3\lib\site-packages (from naas) (0.6.2)
# Collecting escapism==1.0.1
#   Using cached escapism-1.0.1-py2.py3-none-any.whl (3.4 kB)
# Requirement already satisfied: pandas==1.2.4 in c:\users\vp\anaconda3\lib\site-packages (from naas) (1.2.4)
# Requirement already satisfied: pycron==3.0.0 in c:\users\vp\anaconda3\lib\site-packages (from naas) (3.0.0)
# Requirement already satisfied: nbclient==0.5.3 in c:\users\vp\anaconda3\lib\site-packages (from naas) (0.5.3)
# Collecting pysqlite3==0.4.6
#   Using cached pysqlite3-0.4.6.tar.gz (40 kB)
# Requirement already satisfied: jinja2==3.0.3 in c:\users\vp\anaconda3\lib\site-packages (from naas) (3.0.3)
# Requirement already satisfied: ipykernel==5.5.3 in c:\users\vp\anaconda3\lib\site-packages (from naas) (5.5.3)
# Requirement already satisfied: pymongo[srv]==3.11.3 in c:\users\vp\anaconda3\lib\site-packages (from naas) (3.11.3)
# Requirement already satisfied: Pillow==8.3.2 in c:\users\vp\anaconda3\lib\site-packages (from naas) (8.3.2)
# Requirement already satisfied: papermill==2.3.3 in c:\users\vp\anaconda3\lib\site-packages (from naas) (2.3.3)
# Requirement already satisfied: notebook==6.4.1 in c:\users\vp\anaconda3\lib\site-packages (from naas) (6.4.1)
# Collecting html5lib==1.1
#   Using cached html5lib-1.1-py2.py3-none-any.whl (112 kB)
# Requirement already satisfied: sentry-sdk==1.0.0 in c:\users\vp\anaconda3\lib\site-packages (from naas) (1.0.0)
# Collecting mprop==0.16.0
#   Using cached mprop-0.16.0-py3-none-any.whl
# Collecting argparse==1.4.0
#   Using cached argparse-1.4.0-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: chardet<5.0,>=2.0 in c:\users\vp\anaconda3\lib\site-packages (from aiohttp==3.7.4.post0->naas) (4.0.0)
# Requirement already satisfied: async-timeout<4.0,>=3.0 in c:\users\vp\anaconda3\lib\site-packages (from aiohttp==3.7.4.post0->naas) (3.0.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\vp\anaconda3\lib\site-packages (from aiohttp==3.7.4.post0->naas) (5.1.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\vp\anaconda3\lib\site-packages (from aiohttp==3.7.4.post0->naas) (1.6.3)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\vp\anaconda3\lib\site-packages (from aiohttp==3.7.4.post0->naas) (21.4.0)
# Requirement already satisfied: typing-extensions>=3.6.5 in c:\users\vp\anaconda3\lib\site-packages (from aiohttp==3.7.4.post0->naas) (4.1.1)
# Requirement already satisfied: pytz in c:\users\vp\anaconda3\lib\site-packages (from APScheduler==3.8.1->naas) (2021.3)
# Requirement already satisfied: six>=1.4.0 in c:\users\vp\anaconda3\lib\site-packages (from APScheduler==3.8.1->naas) (1.16.0)
# Requirement already satisfied: setuptools>=0.7 in c:\users\vp\anaconda3\lib\site-packages (from APScheduler==3.8.1->naas) (61.2.0)
# Requirement already satisfied: tzlocal!=3.*,>=2.0 in c:\users\vp\anaconda3\lib\site-packages (from APScheduler==3.8.1->naas) (4.2)
# Requirement already satisfied: soupsieve>1.2 in c:\users\vp\anaconda3\lib\site-packages (from beautifulsoup4==4.10.0->naas) (2.3.1)
# Requirement already satisfied: webencodings in c:\users\vp\anaconda3\lib\site-packages (from html5lib==1.1->naas) (0.5.1)
# Requirement already satisfied: tornado>=4.2 in c:\users\vp\anaconda3\lib\site-packages (from ipykernel==5.5.3->naas) (6.1)
# Requirement already satisfied: jupyter-client in c:\users\vp\anaconda3\lib\site-packages (from ipykernel==5.5.3->naas) (6.1.12)
# Requirement already satisfied: traitlets>=4.1.0 in c:\users\vp\anaconda3\lib\site-packages (from ipykernel==5.5.3->naas) (5.1.1)
# Requirement already satisfied: decorator in c:\users\vp\anaconda3\lib\site-packages (from ipython==7.23.1->naas) (5.1.1)
# Requirement already satisfied: backcall in c:\users\vp\anaconda3\lib\site-packages (from ipython==7.23.1->naas) (0.2.0)
# Requirement already satisfied: colorama in c:\users\vp\anaconda3\lib\site-packages (from ipython==7.23.1->naas) (0.4.4)
# Requirement already satisfied: matplotlib-inline in c:\users\vp\anaconda3\lib\site-packages (from ipython==7.23.1->naas) (0.1.2)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\vp\anaconda3\lib\site-packages (from ipython==7.23.1->naas) (3.0.20)
# Requirement already satisfied: pickleshare in c:\users\vp\anaconda3\lib\site-packages (from ipython==7.23.1->naas) (0.7.5)
# Requirement already satisfied: jedi>=0.16 in c:\users\vp\anaconda3\lib\site-packages (from ipython==7.23.1->naas) (0.18.1)
# Requirement already satisfied: pygments in c:\users\vp\anaconda3\lib\site-packages (from ipython==7.23.1->naas) (2.14.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\vp\anaconda3\lib\site-packages (from ipywidgets==7.6.5->naas) (3.5.2)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\vp\anaconda3\lib\site-packages (from ipywidgets==7.6.5->naas) (0.2.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\vp\anaconda3\lib\site-packages (from ipywidgets==7.6.5->naas) (1.0.0)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\vp\anaconda3\lib\site-packages (from ipywidgets==7.6.5->naas) (5.3.0)
# Requirement already satisfied: async-generator in c:\users\vp\anaconda3\lib\site-packages (from nbclient==0.5.3->naas) (1.10)
# Requirement already satisfied: bleach in c:\users\vp\anaconda3\lib\site-packages (from nbconvert==6.0.7->naas) (4.1.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\vp\anaconda3\lib\site-packages (from nbconvert==6.0.7->naas) (0.8.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\vp\anaconda3\lib\site-packages (from nbconvert==6.0.7->naas) (1.5.0)
# Requirement already satisfied: testpath in c:\users\vp\anaconda3\lib\site-packages (from nbconvert==6.0.7->naas) (0.5.0)
# Requirement already satisfied: defusedxml in c:\users\vp\anaconda3\lib\site-packages (from nbconvert==6.0.7->naas) (0.7.1)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\vp\anaconda3\lib\site-packages (from nbconvert==6.0.7->naas) (0.4)
# Requirement already satisfied: jupyterlab-pygments in c:\users\vp\anaconda3\lib\site-packages (from nbconvert==6.0.7->naas) (0.1.2)
# Requirement already satisfied: jupyter-core in c:\users\vp\anaconda3\lib\site-packages (from nbconvert==6.0.7->naas) (4.9.2)
# Requirement already satisfied: argon2-cffi in c:\users\vp\anaconda3\lib\site-packages (from notebook==6.4.1->naas) (21.3.0)
# Requirement already satisfied: Send2Trash>=1.5.0 in c:\users\vp\anaconda3\lib\site-packages (from notebook==6.4.1->naas) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\vp\anaconda3\lib\site-packages (from notebook==6.4.1->naas) (0.13.1)
# Requirement already satisfied: prometheus-client in c:\users\vp\anaconda3\lib\site-packages (from notebook==6.4.1->naas) (0.13.1)
# Requirement already satisfied: pyzmq>=17 in c:\users\vp\anaconda3\lib\site-packages (from notebook==6.4.1->naas) (22.3.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\vp\anaconda3\lib\site-packages (from pandas==1.2.4->naas) (2.8.2)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\vp\anaconda3\lib\site-packages (from pandas==1.2.4->naas) (1.21.5)
# Requirement already satisfied: tqdm>=4.32.2 in c:\users\vp\anaconda3\lib\site-packages (from papermill==2.3.3->naas) (4.64.0)
# Requirement already satisfied: tenacity in c:\users\vp\anaconda3\lib\site-packages (from papermill==2.3.3->naas) (8.0.1)
# Requirement already satisfied: black in c:\users\vp\anaconda3\lib\site-packages (from papermill==2.3.3->naas) (19.10b0)
# Requirement already satisfied: click in c:\users\vp\anaconda3\lib\site-packages (from papermill==2.3.3->naas) (8.0.4)
# Requirement already satisfied: ansiwrap in c:\users\vp\anaconda3\lib\site-packages (from papermill==2.3.3->naas) (0.8.4)
# Requirement already satisfied: pyyaml in c:\users\vp\anaconda3\lib\site-packages (from papermill==2.3.3->naas) (6.0)
# Requirement already satisfied: dnspython<2.0.0,>=1.16.0 in c:\users\vp\anaconda3\lib\site-packages (from pymongo[srv]==3.11.3->naas) (1.16.0)
# Requirement already satisfied: networkx>=1.11 in c:\users\vp\anaconda3\lib\site-packages (from pyvis==0.3.0->naas) (2.7.1)
# Requirement already satisfied: jsonpickle>=1.4.1 in c:\users\vp\anaconda3\lib\site-packages (from pyvis==0.3.0->naas) (3.0.1)
# Requirement already satisfied: aiofiles>=0.6.0 in c:\users\vp\anaconda3\lib\site-packages (from sanic==20.12.2->naas) (23.1.0)
# Requirement already satisfied: websockets<9.0,>=8.1 in c:\users\vp\anaconda3\lib\site-packages (from sanic==20.12.2->naas) (8.1)
# Requirement already satisfied: httpx==0.15.4 in c:\users\vp\anaconda3\lib\site-packages (from sanic==20.12.2->naas) (0.15.4)
# Requirement already satisfied: httptools>=0.0.10 in c:\users\vp\anaconda3\lib\site-packages (from sanic==20.12.2->naas) (0.5.0)
# Requirement already satisfied: rfc3986[idna2008]<2,>=1.3 in c:\users\vp\anaconda3\lib\site-packages (from httpx==0.15.4->sanic==20.12.2->naas) (1.5.0)
# Requirement already satisfied: httpcore==0.11.* in c:\users\vp\anaconda3\lib\site-packages (from httpx==0.15.4->sanic==20.12.2->naas) (0.11.1)
# Requirement already satisfied: sniffio in c:\users\vp\anaconda3\lib\site-packages (from httpx==0.15.4->sanic==20.12.2->naas) (1.2.0)
# Requirement already satisfied: certifi in c:\users\vp\anaconda3\lib\site-packages (from httpx==0.15.4->sanic==20.12.2->naas) (2022.12.7)
# Requirement already satisfied: h11<0.10,>=0.8 in c:\users\vp\anaconda3\lib\site-packages (from httpcore==0.11.*->httpx==0.15.4->sanic==20.12.2->naas) (0.9.0)
# Requirement already satisfied: urllib3>=1.10.0 in c:\users\vp\anaconda3\lib\site-packages (from sentry-sdk==1.0.0->naas) (1.26.9)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\vp\anaconda3\lib\site-packages (from jedi>=0.16->ipython==7.23.1->naas) (0.8.3)
# Requirement already satisfied: pywin32>=1.0 in c:\users\vp\anaconda3\lib\site-packages (from jupyter-core->nbconvert==6.0.7->naas) (302)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\vp\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets==7.6.5->naas) (4.4.0)
# Requirement already satisfied: fastjsonschema in c:\users\vp\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets==7.6.5->naas) (2.15.1)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\vp\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets==7.6.5->naas) (0.18.0)
# Requirement already satisfied: wcwidth in c:\users\vp\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython==7.23.1->naas) (0.2.5)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\vp\anaconda3\lib\site-packages (from requests>=2.25.1->naas) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\vp\anaconda3\lib\site-packages (from requests>=2.25.1->naas) (3.3)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\vp\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook==6.4.1->naas) (2.0.2)
# Requirement already satisfied: pytz-deprecation-shim in c:\users\vp\anaconda3\lib\site-packages (from tzlocal!=3.*,>=2.0->APScheduler==3.8.1->naas) (0.1.0.post0)
# Requirement already satisfied: textwrap3>=0.9.2 in c:\users\vp\anaconda3\lib\site-packages (from ansiwrap->papermill==2.3.3->naas) (0.9.2)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\vp\anaconda3\lib\site-packages (from argon2-cffi->notebook==6.4.1->naas) (21.2.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\vp\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook==6.4.1->naas) (1.15.0)
# Requirement already satisfied: pycparser in c:\users\vp\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook==6.4.1->naas) (2.21)
# Requirement already satisfied: toml>=0.9.4 in c:\users\vp\anaconda3\lib\site-packages (from black->papermill==2.3.3->naas) (0.10.2)
# Requirement already satisfied: typed-ast>=1.4.0 in c:\users\vp\anaconda3\lib\site-packages (from black->papermill==2.3.3->naas) (1.4.3)
# Requirement already satisfied: regex in c:\users\vp\anaconda3\lib\site-packages (from black->papermill==2.3.3->naas) (2022.3.15)
# Requirement already satisfied: appdirs in c:\users\vp\anaconda3\lib\site-packages (from black->papermill==2.3.3->naas) (1.4.4)
# Requirement already satisfied: pathspec<1,>=0.6 in c:\users\vp\anaconda3\lib\site-packages (from black->papermill==2.3.3->naas) (0.7.0)
# Requirement already satisfied: packaging in c:\users\vp\anaconda3\lib\site-packages (from bleach->nbconvert==6.0.7->naas) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\vp\anaconda3\lib\site-packages (from packaging->bleach->nbconvert==6.0.7->naas) (3.0.4)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in c:\users\vp\anaconda3\lib\site-packages (from rich->naas) (2.2.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\vp\anaconda3\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich->naas) (0.1.2)
# Building wheels for collected packages: pysqlite3
#   Building wheel for pysqlite3 (setup.py): started
#   Building wheel for pysqlite3 (setup.py): finished with status 'done'
#   Running setup.py clean for pysqlite3
# Failed to build pysqlite3
# Installing collected packages: pysqlite3, mprop, markdown2, html5lib, escapism, beautifulsoup4, argparse, APScheduler, aiohttp, naas
#     Running setup.py install for pysqlite3: started
#     Running setup.py install for pysqlite3: finished with status 'done'
#   Attempting uninstall: beautifulsoup4
#     Found existing installation: beautifulsoup4 4.11.1
#     Uninstalling beautifulsoup4-4.11.1:
#       Successfully uninstalled beautifulsoup4-4.11.1
#   Attempting uninstall: aiohttp
#     Found existing installation: aiohttp 3.8.1
#     Uninstalling aiohttp-3.8.1:
#       Successfully uninstalled aiohttp-3.8.1
# Successfully installed APScheduler-3.8.1 aiohttp-3.7.4.post0 argparse-1.4.0 beautifulsoup4-4.10.0 escapism-1.0.1 html5lib-1.1 markdown2-2.4.0 mprop-0.16.0 naas-2.10.2 pysqlite3
# Collecting naas_drivers
#   Downloading naas-drivers-0.109.1.tar.gz (105 kB)
#   Downloading naas-drivers-0.109.0.tar.gz (105 kB)
#   Downloading naas-drivers-0.108.1.tar.gz (104 kB)
#   Downloading naas-drivers-0.108.0.tar.gz (104 kB)
#   Downloading naas-drivers-0.107.4.tar.gz (103 kB)
#   Downloading naas-drivers-0.107.3.tar.gz (103 kB)
#   Downloading naas-drivers-0.107.2.tar.gz (103 kB)
#   Downloading naas-drivers-0.107.1.tar.gz (103 kB)
#   Downloading naas-drivers-0.107.0.tar.gz (103 kB)
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\VP\anaconda3\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\VP\\AppData\\Local\\Temp\\pip-install-vclo7zju\\naas-drivers_984c717f3dc64596b6e3a3091a2b6eb4\\setup.py'"'"'; __file__='"'"'C:\\Users\\VP\\AppData\\Local\\Temp\\pip-install-vclo7zju\\naas-drivers_984c717f3dc64596b6e3a3091a2b6eb4\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\VP\AppData\Local\Temp\pip-pip-egg-info-38vo03r2'
#          cwd: C:\Users\VP\AppData\Local\Temp\pip-install-vclo7zju\naas-drivers_984c717f3dc64596b6e3a3091a2b6eb4\
#     Complete output (7 lines):
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "C:\Users\VP\AppData\Local\Temp\pip-install-vclo7zju\naas-drivers_984c717f3dc64596b6e3a3091a2b6eb4\setup.py", line 4, in <module>
#         long_description = fh.read()
#       File "C:\Users\VP\anaconda3\lib\encodings\cp1252.py", line 23, in decode
#         return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#     UnicodeDecodeError: 'charmap' codec can't decode byte 0x8f in position 1129: character maps to <undefined>
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/20/5a/c6f186731cf2b8693215ebe32bb54f368451d62801bac3f0f789cd1ab79b/naas-drivers-0.109.1.tar.gz#sha256=b95d497582d90826f0697198c7bc8de55d0c92c1ef61664673eb34856fde4660 (from https://pypi.org/simple/naas-drivers/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\VP\anaconda3\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\VP\\AppData\\Local\\Temp\\pip-install-vclo7zju\\naas-drivers_78a98a5361d64de7a7ab0703851d27d7\\setup.py'"'"'; __file__='"'"'C:\\Users\\VP\\AppData\\Local\\Temp\\pip-install-vclo7zju\\naas-drivers_78a98a5361d64de7a7ab0703851d27d7\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\VP\AppData\Local\Temp\pip-pip-egg-info-e3xkdy_8'
#          cwd: C:\Users\VP\AppData\Local\Temp\pip-install-vclo7zju\naas-drivers_78a98a5361d64de7a7ab0703851d27d7\
#     Complete output (7 lines):
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "C:\Users\VP\AppData\Local\Temp\pip-install-vclo7zju\naas-drivers_78a98a5361d64de7a7ab0703851d27d7\setup.py", line 4, in <module>
#         long_description = fh.read()
#       File "C:\Users\VP\anaconda3\lib\encodings\cp1252.py", line 23, in decode
#         return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#     UnicodeDecodeError: 'charmap' codec can't decode byte 0x8f in position 1129: character maps to <undefined>
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/6d/6e/2a9c38d3f582688d50b598598b5c67bc27c2074102282a42c66aa42df65f/naas-drivers-0.109.0.tar.gz#sha256=0be5aca74103669e9cfd790da7d71e19458de3a3f5578faf8b4e4029ae60c5e7 (from https://pypi.org/simple/naas-drivers/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\VP\anaconda3\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\VP\\AppData\\Local\\Temp\\pip-install-vclo7zju\\naas-drivers_7484f88df7f34716bdb841fc1a0c2d6a\\setup.py'"'"'; __file__='"'"'C:\\Users\\VP\\AppData\\Local\\Temp\\pip-install-vclo7zju\\naas-drivers_7484f88df7f34716bdb841fc1a0c2d6a\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\VP\AppData\Local\Temp\pip-pip-egg-info-6eykx4b1'
#          cwd: C:\Users\VP\AppData\Local\Temp\pip-install-vclo7zju\naas-drivers_7484f88df7f34716bdb841fc1a0c2d6a\
#     Complete output (7 lines):
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "C:\Users\VP\AppData\Local\Temp\pip-install-vclo7zju\naas-drivers_7484f88df7f34716bdb841fc1a0c2d6a\setup.py", line 4, in <module>
#         long_description = fh.read()
#       File "C:\Users\VP\anaconda3\lib\encodings\cp1252.py", line 23, in decode
#         return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#     UnicodeDecodeError: 'charmap' codec can't decode byte 0x8f in position 1129: character maps to <undefined>
#     ----------------------------------------
#   Downloading naas-drivers-0.106.7.tar.gz (103 kB)
#   Downloading naas-drivers-0.106.6.tar.gz (103 kB)
#   Downloading naas-drivers-0.106.5.tar.gz (103 kB)
#   Downloading naas-drivers-0.106.4.tar.gz (103 kB)
#   Downloading naas-drivers-0.106.3.tar.gz (103 kB)
#   Downloading naas-drivers-0.106.2.tar.gz (103 kB)
#   Downloading naas-drivers-0.106.1.tar.gz (103 kB)
#   Downloading naas-drivers-0.106.0.tar.gz (103 kB)
#   Downloading naas-drivers-0.105.1.tar.gz (103 kB)
#   Downloading naas-drivers-0.105.0.tar.gz (103 kB)
#   Downloading naas-drivers-0.104.2.tar.gz (100 kB)
#   Downloading naas-drivers-0.104.1.tar.gz (100 kB)
#   Downloading naas-drivers-0.104.0.tar.gz (100 kB)
#   Downloading naas-drivers-0.103.4.tar.gz (98 kB)
#   Downloading naas-drivers-0.103.3.tar.gz (98 kB)
#   Downloading naas-drivers-0.103.2.tar.gz (98 kB)
#   Downloading naas-drivers-0.103.1.tar.gz (98 kB)
#   Downloading naas-drivers-0.103.0.tar.gz (98 kB)
#   Downloading naas-drivers-0.102.2.tar.gz (97 kB)
#   Downloading naas-drivers-0.101.2.tar.gz (95 kB)
#   Downloading naas-drivers-0.101.1.tar.gz (95 kB)
#   Downloading naas-drivers-0.101.0.tar.gz (95 kB)
#   Downloading naas-drivers-0.100.0.tar.gz (94 kB)
#   Downloading naas-drivers-0.99.0.tar.gz (94 kB)
#   Downloading naas-drivers-0.98.2.tar.gz (94 kB)
#   Downloading naas-drivers-0.98.1.tar.gz (94 kB)
#   Downloading naas-drivers-0.98.0.tar.gz (94 kB)
#   Downloading naas-drivers-0.97.0.tar.gz (94 kB)
#   Downloading naas-drivers-0.96.13.tar.gz (93 kB)
#   Downloading naas-drivers-0.96.12.tar.gz (93 kB)
#   Downloading naas-drivers-0.96.11.tar.gz (93 kB)
#   Downloading naas-drivers-0.96.9.tar.gz (93 kB)
#   Downloading naas-drivers-0.96.8.tar.gz (93 kB)
#   Downloading naas-drivers-0.96.7.tar.gz (93 kB)
#   Downloading naas-drivers-0.96.6.tar.gz (93 kB)
#   Downloading naas-drivers-0.96.5.tar.gz (93 kB)
#   Downloading naas-drivers-0.96.4.tar.gz (93 kB)
#   Downloading naas-drivers-0.96.3.tar.gz (93 kB)
#   Downloading naas-drivers-0.96.2.tar.gz (93 kB)
#   Downloading naas-drivers-0.96.1.tar.gz (93 kB)
#   Downloading naas-drivers-0.95.0.tar.gz (92 kB)
#   Downloading naas-drivers-0.94.0.tar.gz (92 kB)
#   Downloading naas-drivers-0.93.4.tar.gz (92 kB)
#   Downloading naas-drivers-0.93.3.tar.gz (92 kB)
#   Downloading naas-drivers-0.93.2.tar.gz (92 kB)
#   Downloading naas-drivers-0.93.1.tar.gz (91 kB)
#   Downloading naas-drivers-0.93.0.tar.gz (92 kB)
#   Downloading naas-drivers-0.92.0.tar.gz (90 kB)
#   Downloading naas-drivers-0.91.5.tar.gz (90 kB)
#   Downloading naas-drivers-0.91.4.tar.gz (90 kB)
#   Downloading naas-drivers-0.91.3.tar.gz (90 kB)
#   Downloading naas-drivers-0.91.2.tar.gz (90 kB)
#   Downloading naas-drivers-0.90.0.tar.gz (89 kB)
#   Downloading naas-drivers-0.89.3.tar.gz (86 kB)
#   Downloading naas-drivers-0.89.2.tar.gz (86 kB)
#   Downloading naas-drivers-0.89.1.tar.gz (86 kB)
#   Downloading naas-drivers-0.89.0.tar.gz (86 kB)
#   Downloading naas-drivers-0.88.0.tar.gz (85 kB)
#   Downloading naas-drivers-0.87.0.tar.gz (85 kB)
#   Downloading naas-drivers-0.86.4.tar.gz (85 kB)
#   Downloading naas-drivers-0.86.3.tar.gz (85 kB)
#   Downloading naas-drivers-0.86.2.tar.gz (85 kB)
#   Downloading naas-drivers-0.86.1.tar.gz (85 kB)
#   Downloading naas-drivers-0.86.0.tar.gz (84 kB)
#   Downloading naas-drivers-0.85.2.tar.gz (83 kB)
#   Downloading naas-drivers-0.85.1.tar.gz (83 kB)
#   Downloading naas-drivers-0.85.0.tar.gz (83 kB)
#   Downloading naas-drivers-0.84.1.tar.gz (83 kB)
#   Downloading naas-drivers-0.84.0.tar.gz (83 kB)
#   Downloading naas-drivers-0.83.2.tar.gz (82 kB)
#   Downloading naas-drivers-0.83.1.tar.gz (82 kB)
#   Downloading naas-drivers-0.83.0.tar.gz (83 kB)
#   Downloading naas-drivers-0.82.2.tar.gz (82 kB)
#   Downloading naas-drivers-0.82.1.tar.gz (82 kB)
#   Downloading naas-drivers-0.82.0.tar.gz (82 kB)
#   Downloading naas-drivers-0.81.2.tar.gz (82 kB)
#   Downloading naas-drivers-0.81.1.tar.gz (82 kB)
#   Downloading naas-drivers-0.81.0.tar.gz (82 kB)
#   Downloading naas-drivers-0.80.1.tar.gz (79 kB)
#   Downloading naas-drivers-0.79.0.tar.gz (78 kB)
#   Downloading naas-drivers-0.78.2.tar.gz (78 kB)
#   Downloading naas-drivers-0.78.0.tar.gz (78 kB)
#   Downloading naas-drivers-0.77.3.tar.gz (76 kB)
#   Downloading naas-drivers-0.77.2.tar.gz (76 kB)
#   Downloading naas-drivers-0.77.1.tar.gz (76 kB)
#   Downloading naas-drivers-0.77.0.tar.gz (76 kB)
#   Downloading naas-drivers-0.76.3.tar.gz (76 kB)
#   Downloading naas-drivers-0.76.2.tar.gz (76 kB)
#   Downloading naas-drivers-0.76.1.tar.gz (76 kB)
#   Downloading naas-drivers-0.76.0.tar.gz (76 kB)
# WARNING: Discarding https://files.pythonhosted.org/packages/db/84/23fc3d94aa65d2d3bc95ae5b64532d64ceddcb5cf1f91c3d4786d56ec475/naas-drivers-0.108.1.tar.gz#sha256=d44c9c1ccfa1e58af37480f03d148ed8609692c196d267f894d1bbea9ba89e28 (from https://pypi.org/simple/naas-drivers/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\VP\anaconda3\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\VP\\AppData\\Local\\Temp\\pip-install-vclo7zju\\naas-drivers_b4d3f64d19364b10acf9200342932b09\\setup.py'"'"'; __file__='"'"'C:\\Users\\VP\\AppData\\Local\\Temp\\pip-install-vclo7zju\\naas-drivers_b4d3f64d19364b10acf9200342932b09\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\VP\AppData\Local\Temp\pip-pip-egg-info-_gsuitrx'
#          cwd: C:\Users\VP\AppData\Local\Temp\pip-install-vclo7zju\naas-drivers_b4d3f64d19364b10acf9200342932b09\
#     Complete output (7 lines):
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "C:\Users\VP\AppData\Local\Temp\pip-install-vclo7zju\naas-drivers_b4d3f64d19364b10acf9200342932b09\setup.py", line 4, in <module>
#         long_description = fh.read()
#       File "C:\Users\VP\anaconda3\lib\encodings\cp1252.py", line 23, in decode
#         return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#     UnicodeDecodeError: 'charmap' codec can't decode byte 0x8f in position 1129: character maps to <undefined>
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/2c/5b/44945a26a7e882ee6b6ca7957dcf3d615e844fa536d351afe42089599425/naas-drivers-0.108.0.tar.gz#sha256=ba8d1d3889f08be3a1113e721d4880bc3d088a874b992ddaea3b38871cbc6607 (from https://pypi.org/simple/naas-drivers/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\VP\anaconda3\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\VP\\AppData\\Local\\Temp\\pip-install-vclo7zju\\naas-drivers_ab287467288f4cf1b846f5d5c4321f6e\\setup.py'"'"'; __file__='"'"'C:\\Users\\VP\\AppData\\Local\\Temp\\pip-install-vclo7zju\\naas-drivers_ab287467288f4cf1b846f5d5c4321f6e\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\VP\AppData\Local\Temp\pip-pip-egg-info-yo9qd139'
#          cwd: C:\Users\VP\AppData\Local\Temp\pip-install-vclo7zju\naas-drivers_ab287467288f4cf1b846f5d5c4321f6e\
#     Complete output (7 lines):
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "C:\Users\VP\AppData\Local\Temp\pip-install-vclo7zju\naas-drivers_ab287467288f4cf1b846f5d5c4321f6e\setup.py", line 4, in <module>

# %%
import naas
import pandas as pd
from ipyvizzu import Data, Config, Style
from ipyvizzustory import Story, Slide, Step
import naas_drivers
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-49b4f393dc81> in <module>
# ----> 1 import naas
#       2 import pandas as pd
#       3 from ipyvizzu import Data, Config, Style
#       4 from ipyvizzustory import Story, Slide, Step
#       5 import naas_drivers
#
# ~\anaconda3\lib\site-packages\naas\__init__.py in <module>
#       4 from IPython.core.display import display, Javascript, HTML
#       5 from IPython.display import IFrame
# ----> 6 from .runner.notifications import Notifications
#       7 from .dependency import Dependency
#       8 from .runner.env_var import n_env
#
# ~\anaconda3\lib\site-packages\naas\runner\__init__.py in <module>
# ----> 1 from .runner import Runner  # noqa: F401
#       2 from naas.runner.env_var import n_env  # noqa: F401
#
# ~\anaconda3\lib\site-packages\naas\runner\runner.py in <module>
#       3 from .controllers.scheduler import SchedulerController
#       4 from .controllers.version import VersionController
# ----> 5 from .controllers.auth import AuthController
#       6 from .controllers.manager import ManagerController
#       7 from .controllers.assets import AssetsController
#
# ~\anaconda3\lib\site-packages\naas\runner\controllers\auth.py in <module>
#       1 from sanic.views import HTTPMethodView
# ----> 2 from naas_drivers import naasauth
#       3 from sanic.response import json
#       4 import os
#       5
#
# ModuleNotFoundError: No module named 'naas_drivers'

# %%
df = naas_drivers.gsheet.connect(spreadsheet_id).get(sheet_name=sheet_name)
df

# %%
data = Data()
data.add_data_frame(df)

# %%
Naas
Vizzu - Create interactive data story


Template request | Bug report

Tags: #ipyvizzu #googlesheets #charts #cash

Author: Jeremy Ravenel

Description: Vizzu enables users to create engaging, interactive data stories with ease.

Input
Install packages
# !pip install ipyvizzu 
# !pip install ipyvizzu-story 
Install librairies
import naas
import pandas as pd
from ipyvizzu import Data, Config, Style
from ipyvizzustory import Story, Slide, Step
import naas_drivers
Setup Google Sheet
Using Naas gsheet driver, we will retrieve data from a remote spreadsheet to feed the charts. More on docs.naas.ai

spreadsheet_id = "1YPsBwgBReAaEjVqI6rp3mB2MkGX6tL0kR7x_d07k8WI"
sheet_name = "vizzu_story_example1"
Model
Get data from Google Sheet
df = naas_drivers.gsheet.connect(spreadsheet_id).get(sheet_name=sheet_name)
df
Add data frame to Vizzu
data = Data()
data.add_data_frame(df)
Configure Vizzu slides
story = Story(data=data)
story.set_size("100%", "550px")

slide1 = Slide(
    Step(
        Style(
            {
                "legend": {"label": {"fontSize": "1.1em"}, "paddingRight": "-1em"},
                "plot": {
                    "marker": {"label": {"fontSize": "1.1em"}},
                    "paddingLeft": "10em",
                    "xAxis": {
                        "title": {"color": "#00000000"},
                        "label": {"fontSize": "1.1em"},
                    },
                    "yAxis": {"label": {"fontSize": "1.1em"}},
                },
            }
        ),
        Config(
            {
                "x": {"set": ["Cash percentage [%]", "Maturity"]},
                "y": "Group",
                "color": "Maturity",
                "label": "Cash percentage [%]",
                "title": "💰 What is the cash repartition and maturity per bank?",
            }
        ),
    )
)
story.add_slide(slide1)

slide2 = Slide(
    Step(
        Style({"plot": {"xAxis": {"label": {"color": "#00000000"}}}}),
        Config({"split": True, "title": "🗓 What's the ranking by maturity?"}),
    )
)
story.add_slide(slide2)

slide3 = Slide(
    Step(
        Style({"plot": {"marker": {"label": {"fontSize": "0.916667em"}}}}),
        Config(
            {
                "x": {"set": ["Cash amount", "Maturity"]},
                "label": "Cash amount",
                "title": "⚡️ What's the actual cash positon in M$ by maturity?",
            }
        ),
    )
)
story.add_slide(slide3)

slide4 = Slide()
slide4.add_step(
    Step(
        Style({"plot": {"yAxis": {"title": {"color": "#00000000"}}}}),
        Config(
            {
                "x": "Maturity",
                "y": ["Group", "Cash amount"],
                "split": False,
                "legend": "color",
            }
        ),
    )
)

slide4.add_step(
    Step(
        Style({"plot": {"marker": {"label": {"fontSize": "1.1em"}}}}),
        Config(
            {
                "y": "Cash amount",
                "title": "👀 What's the total cash position in M$ by maturity?",
            }
        ),
    )
)
story.add_slide(slide4)

slide5 = Slide()
slide5.add_step(
    Step(
        Config(
            {"x": ["Interest rate [%]", "Maturity"], "y": None, "label": "Cash amount"}
        )
    )
)

slide5.add_step(
    Step(
        Style({"plot": {"xAxis": {"label": {"color": "#00000000"}}}}),
        Config(
            {
                "coordSystem": "polar",
                "title": "What's the cash repartition in M$ by maturity?",
            }
        ),
    )
)
story.add_slide(slide5)

# %%
story.play()
