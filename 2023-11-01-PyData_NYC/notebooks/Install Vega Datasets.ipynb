# %%
pip install ipyvizzu-story -U
# Out:
# ...
#   Attempting uninstall: ipyvizzu-story
#     Found existing installation: ipyvizzu-story 0.8.0
#     Uninstalling ipyvizzu-story-0.8.0:
#       Successfully uninstalled ipyvizzu-story-0.8.0
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
>>> from vega_datasets import local_data
>>> from vega_datasets import data
>>> local_data.list_datasets()
#>>> data.list_datasets()
# Out:
# ['airports',
#  'anscombe',
#  'barley',
#  'burtin',
#  'cars',
#  'crimea',
#  'driving',
#  'iowa-electricity',
#  'iris',
#  'la-riots',
#  'ohlc',
#  'seattle-temps',
#  'seattle-weather',
#  'sf-temps',
#  'stocks',
#  'us-employment',
#  'wheat']

# %%
>>> data.barley.description
# Out:
# 'This dataset contains crop yields over different regions and different years in the 1930s. It was originally published by Immer in 1934 [1]_, and was popularized by Fisher (1947) [2]_ and Cleveland (1993) [3]_.'

# %%
>>> df = data.wheat()
>>> df
# Out:
#     year  wheat  wages
# 0   1565   41.0   5.00
# 1   1570   45.0   5.05
# 2   1575   42.0   5.08
# 3   1580   49.0   5.12
# 4   1585   41.5   5.15
# 5   1590   47.0   5.25
# 6   1595   64.0   5.54
# 7   1600   27.0   5.61
# 8   1605   33.0   5.69
# 9   1610   32.0   5.78
# 10  1615   33.0   5.94
# 11  1620   35.0   6.01
# 12  1625   33.0   6.12
# 13  1630   45.0   6.22
# 14  1635   33.0   6.30
# 15  1640   39.0   6.37
# 16  1645   53.0   6.45
# 17  1650   42.0   6.50
# 18  1655   40.5   6.60
# 19  1660   46.5   6.75
# 20  1665   32.0   6.80
# 21  1670   37.0   6.90
# 22  1675   43.0   7.00
# 23  1680   35.0   7.30
# 24  1685   27.0   7.60
# 25  1690   40.0   8.00
# 26  1695   50.0   8.50
# 27  1700   30.0   9.00
# 28  1705   32.0  10.00
# 29  1710   44.0  11.00
# 30  1715   33.0  11.75
# 31  1720   29.0  12.50
# 32  1725   39.0  13.00
# 33  1730   26.0  13.30
# 34  1735   32.0  13.60
# 35  1740   27.0  14.00
# 36  1745   27.5  14.50
# 37  1750   31.0  15.00
# 38  1755   35.5  15.70
# ...

# %%
df.attributes
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 df.attributes
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'attributes'

# %% [markdown]
# Lehetséges:
# - cars,
# - la-riots (bár a téma durva),
# - seattle-weather talán, de sok változót származtatni kéne belőle
# - stocks 10 years of daily closing price for AAPL, AMZN, GOOG, IBM, and MSFT
# - us employment
#
# Driving érdekes, van hozzá cikk is, de annyira nem tűnik azért jónak, viszont storytelling szempontból érdekes lehet
# Iris is érdekes, mert sokfelé használják
