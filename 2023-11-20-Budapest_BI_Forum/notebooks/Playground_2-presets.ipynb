# %% [markdown]
# # ipyvizzu Playground 2 - Presets, Styling & Filters
#
# #### If you download this notebook, make sure to check out how to use it in your environment: https://ipyvizzu.vizzuhq.com/latest/environments/

# %%
#!pip install ipyvizzu

# %%
# Import components, add data to pandas data frame

import pandas as pd
from ipyvizzu import Chart, Data, Config, Style

data_frame = pd.read_csv('https://raw.githubusercontent.com/vizzuhq/vizzu-workshops/main/2023-04-25-PyData-Seattle/data/worldpopulation.csv',
                        dtype={'Year': str})
data = Data()
data.add_df(data_frame)

display(data_frame)
# Out:
# C:\Users\VP\AppData\Local\Temp\ipykernel_19228\3050305213.py:9: DeprecationWarning: 'add_data_frame' is deprecated and will be removed in future versions. Use 'add_df' instead - see https://ipyvizzu.vizzuhq.com/0.16/reference/ipyvizzu/animation/#ipyvizzu.animation.Data.add_df
#   data.add_data_frame(data_frame)
#        Region       Subregion                    Country  Year  Period  \
# 0      Africa  Eastern Africa                    Burundi  1953    past
# 1      Africa  Eastern Africa                    Comoros  1953    past
# 2      Africa  Eastern Africa                   Djibouti  1953    past
# 3      Africa  Eastern Africa                    Eritrea  1953    past
# 4      Africa  Eastern Africa                   Ethiopia  1953    past
# ...       ...             ...                        ...   ...     ...
# 6985  Oceania       Polynesia                      Samoa  2098  future
# 6986  Oceania       Polynesia                    Tokelau  2098  future
# 6987  Oceania       Polynesia                      Tonga  2098  future
# 6988  Oceania       Polynesia                     Tuvalu  2098  future
# 6989  Oceania       Polynesia  Wallis and Futuna Islands  2098  future
#
#       Pop_Medium  Pop_High   Pop_Low
# 0        2449089   2449089   2449089
# 1         169748    169748    169748
# 2          66273     66273     66273
# 3         864893    864893    864893
# 4       19184288  19184288  19184288
# ...          ...       ...       ...
# 6985      311591    447953    204322
# 6986        1472      2144       969
# 6987      139471    207034     86954
# 6988       19979     29187     12886
# 6989        5672      8653      3522
#
# [6990 rows x 8 columns]

# %%
# Create empty chart
# Rerun this cell if you want to start over

chart = Chart(width='100%', height='360px')

chart.animate(data)

# %%
chart.animate(
# Use filtering
    
    Data.filter(
        "record.Region == 'Africa'"  #'(record.Region == 'Africa' || record.Region == 'Asia') && record.Region == 'past' '
    ),

# Use a preset    
    Config.stackedColumn({ #groupedColumn (stackedBy), groupedColumn (groupedBy), percentageArea (stackedBy), stream (stackedBy), violin (splittedBy)
            'x': 'Year',
            'y': 'Pop_Medium',
            'stackedBy': 'Region',
            'title': 'Population of Africa 1953-2018',
        }),

# Set custom style    
    Style({ 
            'plot': {
                'paddingLeft': '15em',
                'marker': { 'label' :{ 
                    'position':'top', #bottom, 
                    'numberFormat' : 'prefixed',
                    'maxFractionDigits' : '1',
                    'numberScale':'shortScaleSymbolUS'
                }},
                     'xAxis': { 'label': { 'angle': '-45deg',  'numberScale':'shortScaleSymbolUS'}},
                     'yAxis': { 'label': { 'numberScale':'shortScaleSymbolUS'}}  
                },
            #    'legend' : {'width' : '15em'},
    })
)

chart.feature('tooltip', True)

# %%
chart.animate(
   Config.line({ #stackedColumn (stackedBy), groupedColumn (groupedBy), percentageArea (stackedBy), stream (stackedBy), violin (splittedBy)
            'x': 'Year',
            'y': 'Pop_Medium',
            'dividedBy': 'Subregion',
            'title': 'Population of Africa 1953-2018',
        }),
)

# %%
chart.animate(
   Config.stackedColumn({ #stackedColumn (stackedBy), groupedColumn (groupedBy), percentageArea (stackedBy), stream (stackedBy), violin (splittedBy)
            'x': 'Year',
            'y': 'Pop_Medium',
            'stackedBy': 'Subregion',
            'title': 'Population of Africa 1953-2018 (%)',
        }),
)
chart.feature('tooltip', True)

# %%
chart.animate(
    Data.filter(None),
    Config({
        'title': 'Population of the World by Subregions (%)'
    })
)
